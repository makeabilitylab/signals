# %%
"Hello World"
# Out:
# 'Hello World'

# %%
# Let's make a list of values
myList = [1, 2, 3, 4, 5]
print(myList)
# Out:
# [1, 2, 3, 4, 5]

# %%
# Let's graph our list!
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(myList)

# %%
# Let's make the graph prettier!
fig, ax = plt.subplots()
ax.plot(myList)
ax.set(xlabel='My x label!', ylabel='My y label. :)',
       title='We have reached linearity!')
ax.grid()

# %%
# Manually creating lists is no fun, let's make a list automagically
# range takes a start val, end val, and step
myList2 = list(range(1, 10, 2))
print(myList2)
# Out:
# [1, 3, 5, 7, 9]

# %%
# Let's plot both of these lists
fig, ax = plt.subplots()
ax.plot(myList, label="original list")
ax.plot(myList2, label="auto list")
ax.legend()
ax.grid()

# %%
# We can also have HashMaps or dictionaries--Python calls them dicts
mapNamesToAges = {"Frank" : 1.5, "Teddy" : 3.3, "Susan": 4.5, "Billy": 4.4, "Frankie" : 6}
print(mapNamesToAges)
# Out:
# {'Frank': 1.5, 'Teddy': 3.3, 'Susan': 4.5, 'Billy': 4.4, 'Frankie': 6}

# %%
# Let's plot them all!
fig, ax = plt.subplots()
ax.plot(myList, label="original list")
ax.plot(myList2, label="auto list")
ax.plot(mapNamesToAges.values(), label="ages")
ax.legend()
ax.grid()

# %% [markdown]
# # Markdown Support!
# Jupyter Notebook also supports markdown! From the dropdown menu, select `Cell->Cell Type->Markdown`
